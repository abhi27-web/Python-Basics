# %% [markdown]
# ## Importing Modules

# %%
from PIL import Image, ImageEnhance

# %% [markdown]
# ## Brightness

# %%
# Opening Image
im = Image.open("img.png")
display(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x188 at 0x2AD15B5DCC8>

# %%
# Creating object of Brightness class
im3 = ImageEnhance.Brightness(im)
  
# showing resultant image
new=im3.enhance(2.0)

display(new)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x188 at 0x2AD15B47888>

# %%
collage = Image.new("RGBA", (400,500))

img = Image.open("PM.jpg")
img = img.resize((100,100))

filter = ImageEnhance.Brightness(img)

c=0.7
for i in range(0,500,100):
    for j in range(0,400,100):
        new_img = filter.enhance(c)
        collage.paste(new_img, (j,i))
        c+=0.1
display(collage)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x500 at 0x2AD15B6BB48>

# %% [markdown]
# ## Colour

# %%
collage = Image.new("RGBA", (400,500))

img = Image.open("PM.jpg")
img = img.resize((100,100))

filter = ImageEnhance.Color(img)

c=0.7
for i in range(0,500,100):
    for j in range(0,400,100):
        new_img = filter.enhance(c)
        collage.paste(new_img, (j,i))
        c+=0.1
display(collage)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x500 at 0x2AD15B7C548>

# %% [markdown]
# ## Contrast

# %%
collage = Image.new("RGBA", (400,500))

img = Image.open("PM.jpg")
img = img.resize((100,100))

filter = ImageEnhance.Contrast(img)

c=0.7
for i in range(0,500,100):
    for j in range(0,400,100):
        new_img = filter.enhance(c)
        collage.paste(new_img, (j,i))
        c+=0.1
display(collage)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x500 at 0x2AD06458D08>

# %% [markdown]
# ## Sharpness

# %%
collage = Image.new("RGBA", (400,500))

img = Image.open("PM.jpg")
img = img.resize((100,100))

filter = ImageEnhance.Color(img)

c=0.7
for i in range(0,500,100):
    for j in range(0,400,100):
        new_img = filter.enhance(c)
        collage.paste(new_img, (j,i))
        c+=0.1
display(collage)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x500 at 0x2AD06458D08>
